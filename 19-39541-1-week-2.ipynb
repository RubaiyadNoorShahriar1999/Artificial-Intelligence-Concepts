# %% [markdown]
# # Rubaiyad Noor Shahriar
#
# # ID: 19-39541-1
#
# # Section: M

# %% [markdown]
# # List Practice

# %%
List1 = [ 'a' ,'b' ,'c', 'd']

# %%
List2 = [ 1, 2 ,  3 , 4 , 5 ]

# %%
List = List1 + List2

# %%
List
# Out:
# ['a', 'b', 'c', 'd', 1, 2, 3, 4, 5]

# %%
List1
# Out:
# ['a', 'b', 'c', 'd']

# %%
List2
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # for loop

# %%
for x in List2:
    4 in List2

# %%
List2.append(10)

# %%
List2
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
List1.extend(['x' ,'y', 'z'])

# %%
List1
# Out:
# ['a', 'b', 'c', 'd', 'x', 'y', 'z']

# %%
List1.sort()

# %%
List1
# Out:
# ['a', 'b', 'c', 'd', 'x', 'y', 'z']

# %%
List2.sort()

# %%
List2
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
List2.insert(11,22) #list2 consists of integers

# %%
List1.reverse()

# %%
List1
# Out:
# ['z', 'y', 'x', 'd', 'c', 'b', 'a']

# %%
List1.reverse()

# %%
List1
# Out:
# ['a', 'b', 'c', 'd', 'x', 'y', 'z']

# %% [markdown]
# # del Keyword Usage

# %%
del List1[-1]

# %%
del List2[3:5]

# %%
List2
# Out:
# [1, 2, 3, 10, 22]

# %%
List2[2:5]= []

# %%
List2
range(5)
# Out:
# range(0, 5)

# %%
range(0,5)
# Out:
# range(0, 5)

# %%
for a in [5,6,7,8,9]:
   # a.reverse()
    print(a)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
List = ['Rubaiyad' , 'Noor' ,'Shahriar', 'HRIDOY']

# %%
List[1]
# Out:
# 'Noor'

# %%
List[1:-1]
# Out:
# ['Noor', 'Shahriar']

# %%
List[1: ]
# Out:
# ['Noor', 'Shahriar', 'HRIDOY']

# %% [markdown]
# # Matrix 3D

# %%
matrix = [[1,0,0] ,[0,1,0],[0,0,1]]

# %%
matrix[1]
# Out:
# [0, 1, 0]

# %%
matrix[1:3] #matrix[1][3] doesn't work
# Out:
# [[0, 1, 0], [0, 0, 1]]

# %%
matrix = [[2,3,5],
          [6,7,8],
          [9,10,11]]

# %%
matrix[2][2]
# Out:
# 11

# %% [markdown]
# # Changing List In-Place

# %%
List = ['Rubaiyad' , 'Noor' , 'Shahriar']

# %%
List.append('Hridoy')

# %%
List
# Out:
# ['Rubaiyad', 'Noor', 'Shahriar', 'Hridoy']

# %%
List.sort()

# %%
List
# Out:
# ['Hridoy', 'Noor', 'Rubaiyad', 'Shahriar']

# %% [markdown]
# # Dictionaries

# %%
dic = { 'Rubaiyad':0 , 'Noor':1 ,'Shahriar':2 }

# %%
'Noor' in dic
# Out:
# True

# %%
dic.keys() #to show the keys
# Out:
# dict_keys(['Rubaiyad', 'Noor', 'Shahriar'])

# %%
dic.values() #to show values
# Out:
# dict_values([0, 1, 2])

# %%
len(dic)
# Out:
# 3

# %%
dic2 = {'Hridoy':3}

# %%
dic2.update(dic)

# %%
dic
# Out:
# {'Rubaiyad': 0, 'Noor': 1, 'Shahriar': 2}

# %%
dic2
# Out:
# {'Hridoy': 3, 'Rubaiyad': 0, 'Noor': 1, 'Shahriar': 2}

# %%
len(dic2)
# Out:
# 4

# %%
dic2.pop('Noor')
# Out:
# 1

# %%
dic2
# Out:
# {'Hridoy': 3, 'Rubaiyad': 0, 'Shahriar': 2}

# %%
dic2.get('Noor')

# %%
dic2
# Out:
# {'Hridoy': 3, 'Rubaiyad': 0, 'Shahriar': 2}

# %%
dic2.get('Rubaiyad') #returns value
# Out:
# 0

# %%
dic2.get(2)

# %%
dic2
# Out:
# {'Hridoy': 3, 'Rubaiyad': 0, 'Shahriar': 2}

# %%
 dic2.update(dic)

# %%
dic
# Out:
# {'Rubaiyad': 0, 'Noor': 1, 'Shahriar': 2}

# %%
dic2
# Out:
# {'Hridoy': 3, 'Rubaiyad': 0, 'Shahriar': 2, 'Noor': 1}

# %%
dic.get('Hridoy' ,7)
# Out:
# 7

# %% [markdown]
# # Dictionaries for Data Structures

# %%
Matrix ={}
Matrix[(11,22,33)] = 123
Matrix[(44,55,66)] = 456

# %%
Matrix
# Out:
# {(11, 22, 33): 123, (44, 55, 66): 456}

# %%
Matrix1 = ['x' ,'y', 'z']

# %%
Matrix1 = Matrix

# %%
Matrix1
# Out:
# {(11, 22, 33): 123, (44, 55, 66): 456}

# %% [markdown]
# # Interactive Loops

# %%
while True:
    reply = input('Enter Text: ')
    if reply == 'c': continue
    print(reply)
    if reply == 'stop': break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# /opt/conda/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     806         try:
# --> 807             msg_list = socket.recv_multipart(mode, copy=copy)
#     808         except zmq.ZMQError as e:
#
# /opt/conda/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# --> 566         parts = [self.recv(flags, copy=copy, track=track)]
#     567         # have first part already, only loop while more to receive
#
# ...

# %%
while True:
    Order = input('Enter Your Food name: ')
    if Order == 'water'or 'pizza' or 'fried rice' or 'chiken' or 'coffee' :
        print('Your', Order , 'will be serverd')
    if Order == 'nothing': 
        print('Thanks for visiting us')
# Out:
# Enter Your Food name: pizza
# Your pizza will be serverd
# Enter Your Food name: nothing
# Your nothing will be serverd
# Thanks for visiting us
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# /opt/conda/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     806         try:
# --> 807             msg_list = socket.recv_multipart(mode, copy=copy)
#     808         except zmq.ZMQError as e:
#
# /opt/conda/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# ...

# %%
while True:
    Order = input('Enter Your Food name: ')
    if( Order == 'water'or 'pizza' or 'fried rice' or 'chiken' or 'coffee' ):
        print('Your', Order , 'will be serverd')
    else: print('Thanks for visiting us')
# Out:
# Enter Your Food name: mewpof
# Your mewpof will be serverd
